# %%
import xarray as xr
import pandas as pd

# %%
ds = xr.open_dataset('64b3e54c44511d1ad5c052453599b333.nc')
df = ds.to_dataframe()
df = df.reset_index()
df = df.drop(['number','expver'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('C:\\Users\\nacho\\OneDrive\\Escritorio\\UV - agua\\BBDD\\Copernicus - climate ERA5\\64b3e54c44511d1ad5c052453599b333.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'b99c5c68-0750-4630-854d-511061e8e8f5']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ds = xr.open_dataset('64b3e54c44511d1ad5c052453599b333.nc')
#       2 df = ds.to_dataframe()
#       3 df = df.reset_index()
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\api.py:573, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     561 decoders = _resolve_decoders_kwargs(
#     562     decode_cf,
#     563     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     569     decode_coords=decode_coords,
#     570 )
#     572 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 573 backend_ds = backend.open_dataset(
#     574     filename_or_obj,
#     575     drop_variables=drop_variables,
#     576     **decoders,
#     577     **kwargs,
#     578 )
#     579 ds = _dataset_from_backend_dataset(
#     580     backend_ds,
#     581     filename_or_obj,
#    (...)
#     591     **kwargs,
#     592 )
#     593 return ds
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\netCDF4_.py:603, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     582 def open_dataset(  # type: ignore[override]  # allow LSP violation, not supporting **kwargs
#     583     self,
#     584     filename_or_obj: str | os.PathLike[Any] | BufferedIOBase | AbstractDataStore,
#    (...)
#     600     autoclose=False,
#     601 ) -> Dataset:
#     602     filename_or_obj = _normalize_path(filename_or_obj)
# --> 603     store = NetCDF4DataStore.open(
#     604         filename_or_obj,
#     605         mode=mode,
#     606         format=format,
#     607         group=group,
#     608         clobber=clobber,
#     609         diskless=diskless,
#     610         persist=persist,
#     611         lock=lock,
#     612         autoclose=autoclose,
#     613     )
#     615     store_entrypoint = StoreBackendEntrypoint()
#     616     with close_on_error(store):
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\netCDF4_.py:400, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     394 kwargs = dict(
#     395     clobber=clobber, diskless=diskless, persist=persist, format=format
#     396 )
#     397 manager = CachingFileManager(
#     398     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     399 )
# --> 400 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\netCDF4_.py:347, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     345 self._group = group
#     346 self._mode = mode
# --> 347 self.format = self.ds.data_model
#     348 self._filename = self.ds.filepath()
#     349 self.is_remote = is_remote_uri(self._filename)
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\netCDF4_.py:409, in NetCDF4DataStore.ds(self)
#     407 @property
#     408 def ds(self):
# --> 409     return self._acquire()
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\netCDF4_.py:403, in NetCDF4DataStore._acquire(self, needs_lock)
#     402 def _acquire(self, needs_lock=True):
# --> 403     with self._manager.acquire_context(needs_lock) as root:
#     404         ds = _nc4_require_group(root, self._group, self._mode)
#     405     return ds
#
# File ~\mambaforge\envs\myenv\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File ~\mambaforge\envs\myenv\Lib\site-packages\xarray\backends\file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src\\netCDF4\\_netCDF4.pyx:2470, in netCDF4._netCDF4.Dataset.__init__()
#
# File src\\netCDF4\\_netCDF4.pyx:2107, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\nacho\\OneDrive\\Escritorio\\UV - agua\\BBDD\\Copernicus - climate ERA5\\64b3e54c44511d1ad5c052453599b333.nc'

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Suponiendo que tu DataFrame se llama df y tiene columnas 'lat', 'lon'
# Reemplaza 'lat' y 'lon' con los nombres de tus columnas correspondientes
latitudes = df['latitude']
longitudes = df['longitude']

# Crear la figura
fig = plt.figure(figsize=(10, 5))

# Crear el eje usando la proyección de Mercator
ax = plt.axes(projection=ccrs.PlateCarree())

# Agregar características como costas y fronteras
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Definir las extensiones del mapa (España aproximadamente)
ax.set_extent([-10, 5, 35, 45], crs=ccrs.PlateCarree())  # [longitud oeste, longitud este, latitud sur, latitud norte]

# Graficar los puntos en el mapa
ax.scatter(longitudes, latitudes, color='red', s=10, transform=ccrs.PlateCarree())

# Títulos
plt.title('Distribución de puntos geográficos en España')
plt.show()

# %%
df_cuencaHidro = pd.read_csv('../Cuenca hidrográfica Juca SI/F2796_Rios_y_Canales_ROEA/F2796_M1_Actuales.csv')

# %%
df_rios_id = pd.read_csv('../df_rios_canales_id.csv')
df_albufera_id = pd.read_csv('../df_albufera_id.csv')
df_embalses_id = pd.read_csv('../df_embalses_maps_id.csv', sep=';')
df_copernicus = pd.read_csv('../df_copernicus.csv')

# %%
coord_copernicus = df_copernicus[df_copernicus['date'] == '1960-01-01'][['latitude', 'longitude']]
coord_df_rios_id  = df_rios_id[['latitude', 'longitude']]
coord_df_albufera_id = df_albufera_id[['latitude', 'longitude']]
coord_df_embalses_id = df_embalses_id[['latitude', 'longitude']]
coord_quant = pd.concat([coord_df_rios_id, coord_df_albufera_id, coord_df_embalses_id])

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Suponiendo que tus DataFrames se llaman df y df_cuencaHidro
# Y que ambos tienen columnas 'latitude' y 'longitude' (ajusta si tienen otros nombres)
latitudes1 = coord_copernicus['latitude']
longitudes1 = coord_copernicus['longitude']

latitudes2 = coord_df_embalses_id['latitude']
longitudes2 = coord_df_embalses_id['longitude']

# Crear la figura
fig = plt.figure(figsize=(10, 5))

# Crear el eje usando la proyección de Mercator
ax = plt.axes(projection=ccrs.PlateCarree())

# Agregar características como costas y fronteras
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Definir las extensiones del mapa (España aproximadamente)
ax.set_extent([-10, 5, 35, 45], crs=ccrs.PlateCarree())  # [longitud oeste, longitud este, latitud sur, latitud norte]

# Graficar los puntos del primer DataFrame en el mapa
ax.scatter(longitudes1, latitudes1, color='red', s=10, label='Puntos copernicus', transform=ccrs.PlateCarree())

# Graficar los puntos del segundo DataFrame en el mismo mapa
ax.scatter(longitudes2, latitudes2, color='blue', s=10, label='Estaciones cuenca hidrográfica', transform=ccrs.PlateCarree())

# Agregar leyenda para identificar cada conjunto de puntos
plt.legend()

# Títulos
plt.title('Distribución de puntos geográficos en España (Copernicus, Estaciones cuenca)')
plt.show()

# %%
# Suponiendo que tus DataFrames se llaman df y df_cuencaHidro
# Y que ambos tienen columnas 'latitude' y 'longitude' (ajusta si tienen otros nombres)
latitudes1 = coord_copernicus['latitude']
longitudes1 = coord_copernicus['longitude']

latitudes2 = coord_df_rios_id['latitude']
longitudes2 = coord_df_rios_id['longitude']

latitudes3 = coord_df_albufera_id['latitude']
longitudes3 = coord_df_albufera_id['longitude']

latitudes4 = coord_df_embalses_id['latitude']
longitudes4 = coord_df_embalses_id['longitude']
# Crear la figura
fig = plt.figure(figsize=(10, 5))

# Crear el eje usando la proyección de Mercator
ax = plt.axes(projection=ccrs.PlateCarree())

# Agregar características como costas y fronteras
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Definir las extensiones del mapa (España aproximadamente)
ax.set_extent([-10, 5, 35, 45], crs=ccrs.PlateCarree())  # [longitud oeste, longitud este, latitud sur, latitud norte]

ax.scatter(longitudes1, latitudes1, color='red', s=10, marker='o', label='Puntos copernicus', transform=ccrs.PlateCarree())  # Círculo
ax.scatter(longitudes2, latitudes2, color='blue', s=10, marker='s', label='Estaciones ríos y canales', transform=ccrs.PlateCarree())  # Cuadrado
ax.scatter(longitudes3, latitudes3, color='yellow', s=10, marker='^', label='Estaciones albufera', transform=ccrs.PlateCarree())  # Triángulo hacia arriba
ax.scatter(longitudes4, latitudes4, color='brown', s=10, marker='D', label='Estaciones embalses', transform=ccrs.PlateCarree())  # Diamante


# Agregar leyenda para identificar cada conjunto de puntos
plt.legend()

# Títulos
plt.title('Distribución de Estaciones Cuenca Hidrográfica')
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.patches as patches

# Suponiendo que tus DataFrames se llaman coord_copernicus, coord_df_rios_id, coord_df_albufera_id, coord_df_embalses_id
latitudes1 = coord_copernicus['latitude']
longitudes1 = coord_copernicus['longitude']

latitudes2 = coord_df_rios_id['latitude']
longitudes2 = coord_df_rios_id['longitude']

latitudes3 = coord_df_albufera_id['latitude']
longitudes3 = coord_df_albufera_id['longitude']

latitudes4 = coord_df_embalses_id['latitude']
longitudes4 = coord_df_embalses_id['longitude']

# Crear la figura
fig = plt.figure(figsize=(10, 5))

# Crear el eje usando la proyección de Mercator
ax = plt.axes(projection=ccrs.PlateCarree())

# Agregar características como costas y fronteras
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Definir las extensiones del mapa (España aproximadamente)
ax.set_extent([-10, 5, 35, 45], crs=ccrs.PlateCarree())  # [longitud oeste, longitud este, latitud sur, latitud norte]

# Tamaño del píxel (grados de longitud y latitud)

# Agregar los "píxeles" de Copernicus en vez de puntos
pixel_size = 0.5  # Ajusta este valor para cambiar el tamaño de los píxeles

# Agregar los "píxeles" de Copernicus en vez de puntos
for lon, lat in zip(longitudes1, latitudes1):
    pixel = patches.Rectangle((lon - pixel_size / 2, lat - pixel_size / 2), 
                              pixel_size, pixel_size,
                              edgecolor='red', facecolor='red', alpha=0.5, transform=ccrs.PlateCarree())
    ax.add_patch(pixel)

# Graficar los puntos del segundo DataFrame en el mismo mapa (ríos y canales)
ax.scatter(longitudes2, latitudes2, color='blue', s=10, marker='s', label='Estaciones ríos y canales', transform=ccrs.PlateCarree())  # Cuadrado

# Graficar los puntos del tercer DataFrame en el mismo mapa (albufera)
ax.scatter(longitudes3, latitudes3, color='yellow', s=10, marker='^', label='Estaciones albufera', transform=ccrs.PlateCarree())  # Triángulo

# Graficar los puntos del cuarto DataFrame en el mismo mapa (embalses)
ax.scatter(longitudes4, latitudes4, color='brown', s=10, marker='D', label='Estaciones embalses', transform=ccrs.PlateCarree())  # Diamante

# Agregar leyenda para identificar cada conjunto de puntos
plt.legend()

# Títulos
plt.title('Distribución de Estaciones Cuenca Hidrográfica')
plt.show()

# %%
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from shapely.geometry import Point
import geopandas as gpd

# Crear el eje usando la proyección PlateCarree
ax = plt.axes(projection=ccrs.PlateCarree())

# Cargar la característica de masas terrestres (tierra)
land = cfeature.NaturalEarthFeature('physical', 'land', '10m')

# Convertir longitudes y latitudes en geometría de puntos
gdf_embalses = gpd.GeoDataFrame({
    'latitude': coord_df_embalses_id['latitude'],
    'longitude': coord_df_embalses_id['longitude']
}, geometry=gpd.points_from_xy(coord_df_embalses_id['longitude'], coord_df_embalses_id['latitude']))

# Crear una máscara de puntos que estén fuera de la tierra
# El feature de 'land' se toma como la representación de tierra firme
land_geom = list(land.geometries())  # Geometrías de la tierra firme

# Filtrar los embalses que están fuera de tierra (en el mar)
embalses_en_mar = gdf_embalses[~gdf_embalses['geometry'].apply(lambda x: any([x.within(land_poly) for land_poly in land_geom]))]

# Mostrar los embalses que están en el mar
print(embalses_en_mar)

# Mostrar visualización
plt.scatter(gdf_embalses['longitude'], gdf_embalses['latitude'], color='brown', s=10, label='Estaciones embalses')
plt.scatter(embalses_en_mar['longitude'], embalses_en_mar['latitude'], color='blue', s=20, label='Embalses en el mar')

# Títulos y leyendas
plt.title('Embalses ubicados en el mar')
plt.legend()
plt.show()
# Out:
# C:\Users\nacho\mambaforge\envs\myenv\Lib\site-packages\cartopy\io\__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
#     latitude  longitude                 geometry
# 3    38.3205    -0.1549  POINT (-0.1549 38.3205)
# 6    38.4858    -0.2119  POINT (-0.2119 38.4858)
# 7    39.3551     0.5618   POINT (0.5618 39.3551)
# 12   38.4052    -0.1127  POINT (-0.1127 38.4052)
# 15   39.5616    -0.1949  POINT (-0.1949 39.5616)
# 16   39.5329     0.3126   POINT (0.3126 39.5329)
# 22   39.1424     0.5537   POINT (0.5537 39.1424)
# 23   39.1646     0.5102   POINT (0.5102 39.1646)
# 24   39.0805     0.3858   POINT (0.3858 39.0805)
# 26   38.5629     0.2836   POINT (0.2836 38.5629)
# 27   39.4721    -0.2231  POINT (-0.2231 39.4721)
# 31   38.3009     0.3324   POINT (0.3324 38.3009)
# 32   38.3354     0.1714   POINT (0.1714 38.3354)
# 33   38.1833     0.4311   POINT (0.4311 38.1833)
# 34   38.2952    -0.4734  POINT (-0.4734 38.2952)

# %%
indexes = []
for index,row in coord_df_embalses_id.iterrows():
    for index2,row2 in embalses_en_mar.iterrows():
        if row['latitude'] == row2['latitude'] and row['longitude'] == row2['longitude']:
            indexes.append(index)
df_embalses_mar = df_embalses_id.loc[indexes]

# %%
df_embalses_mar = df_embalses_id.loc[indexes]

def decimal_a_dms(coordenada, tipo='lat'):
    grados = int(coordenada)
    minutos_dec = abs(coordenada - grados) * 60
    minutos = int(minutos_dec)
    segundos = (minutos_dec - minutos) * 60
    
    # Determinar la dirección (N/S para latitudes, E/O para longitudes)
    if tipo == 'lat':
        direccion = 'N' if grados >= 0 else 'S'
    elif tipo == 'lon':
        direccion = 'E' if grados >= 0 else 'O'
    
    return f"{abs(grados)}°{minutos}'{segundos:.2f}\" {direccion}"

df_embalses_mar['latitude_dms'] = df_embalses_mar['latitude'].apply(lambda x: decimal_a_dms(x, 'lat'))
df_embalses_mar['longitude_dms'] = df_embalses_mar['longitude'].apply(lambda x: decimal_a_dms(x, 'lon'))

# %%
df_embalses_mar
# Out:
#     id_station               place  longitude  latitude  pixel  \
# 3         8004            AMADORIO    -0.1549   38.3205      3
# 6         8007           BENIARRES    -0.2119   38.4858      6
# 7         8008               BUSEO     0.5618   39.3551      7
# 12        8015           GUADALEST    -0.1127   38.4052     12
# 15        8018                ONDA    -0.1949   39.5616     15
# 16        8019              REGAJO     0.3126   39.5329     16
# 22        8028  MUELA, LA (BOMBEO)     0.5537   39.1424     22
# 23        8029       NARANJERO, EL     0.5102   39.1646     23
# 24        8030                TOUS     0.3858   39.0805     24
# 26        8032              BELLUS     0.2836   38.5629     26
# 27        8033               ALGAR    -0.2231   39.4721     27
# 31        8931                TIBI     0.3324   38.3009     31
# 32        8932              RELLEU     0.1714   38.3354     32
# 33        8933               ELCHE     0.4311   38.1833     33
# 34        8934                ELDA    -0.4734   38.2952     34
#
#       latitude_dms  longitude_dms
# 3   38°19'13.80" N   0°9'17.64" E
# 6    38°29'8.88" N  0°12'42.84" E
# 7   39°21'18.36" N  0°33'42.48" E
# 12  38°24'18.72" N   0°6'45.72" E
# 15  39°33'41.76" N  0°11'41.64" E
# 16  39°31'58.44" N  0°18'45.36" E
# 22   39°8'32.64" N  0°33'13.32" E
# 23   39°9'52.56" N  0°30'36.72" E
# 24   39°4'49.80" N   0°23'8.88" E
# 26  38°33'46.44" N   0°17'0.96" E
# 27  39°28'19.56" N  0°13'23.16" E
# 31   38°18'3.24" N  0°19'56.64" E
# 32   38°20'7.44" N  0°10'17.04" E
# 33  38°10'59.88" N  0°25'51.96" E
# 34  38°17'42.72" N  0°28'24.24" E
